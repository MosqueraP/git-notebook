# %%
nombre = 'Howard'
apellido = 'Mosquera'

print('Ingresa tu nombre por favor \n')
print('Mi nombre es ',nombre,'y mi apellido es',apellido )
# Out:
# Ingresa tu nombre por favor
#
# Mi nombre es  Howard y mi apellido es Mosquera

# %% [markdown]
# El siguiente programa tiene la fidalidad de implemntar una pregunta, donde se le preguntara al usuario que por faovr introduzca su nombre para luego ser saludado de una manera muy amable y darle la biernvenida al curso dque se está llevandoa cabao
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
